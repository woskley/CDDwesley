...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362515  ...      NaN    NaN    NaN    NaN    NaN           NaN  1.150000e+02
# 362518  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362524  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362534  ...        1      3     11      3      1  8.000000e+02  8.000000e+02
# 362537  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362541  ...        1      5     12      8      1  1.600000e+03  1.600000e+03
# 362542  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362549  ...        7      2     10      5      2  1.000000e+02  1.000000e+02
#
#                V4742         V4750  V4729
# 5       2.660000e+02  2.660000e+02    243
# 6       2.660000e+02  2.660000e+02    243
# 20      2.800000e+02  2.800000e+02    243
# 38      6.660000e+02  6.660000e+02    243
# 54      2.710000e+02  2.710000e+02    243
# 64      8.000000e+02  8.000000e+02    243
# 82      2.000000e+03  2.000000e+03    244
# 86      8.620000e+02  8.620000e+02    243
# 97      3.390000e+02  3.390000e+02    244
# 101     2.120000e+02  2.120000e+02    243
# 104     2.120000e+02  2.120000e+02    243
# 118     0.000000e+00  0.000000e+00    244
# 130     1.090000e+02  1.090000e+02    244
# 143     0.000000e+00  0.000000e+00    243
# 144     0.000000e+00  0.000000e+00    243
# 149     4.560000e+02  4.560000e+02    244
# 168     1.660000e+02  1.660000e+02    243
# 176     5.800000e+02  5.800000e+02    244
# 179     6.280000e+02  6.280000e+02    243
# 191     1.800000e+03  1.800000e+03    244
# 192     1.800000e+03  1.800000e+03    244
# 195     6.660000e+02  6.660000e+02    243
# 204     3.550000e+02  3.550000e+02    243
# 214     1.000000e+12  4.000000e+02    243
# 216     4.500000e+02  4.500000e+02    243
# 227     6.400000e+02  6.400000e+02    243
# 235     1.200000e+03  1.200000e+03    243
# 240     7.000000e+02  7.000000e+02    243
# 241     7.000000e+02  7.000000e+02    244
# 247     2.460000e+02  2.460000e+02    243
# ...              ...           ...    ...
# 362325  7.500000e+02  7.500000e+02    299
# 362337  5.150000e+02  5.150000e+02    299
# 362344  5.250000e+02  5.250000e+02    299
# 362350  2.900000e+02  3.760000e+02    299
# 362354  2.900000e+02  1.600000e+02    300
# 362360  1.710000e+02  1.710000e+02    299
# 362372  4.520000e+02  4.520000e+02    300
# 362375  5.590000e+02  5.590000e+02    299
# 362383  1.000000e+12  1.000000e+12    299
# 362389  6.180000e+02  6.180000e+02    299
# 362391  3.390000e+02  3.390000e+02    299
# 362402  1.266000e+03  1.266000e+03    299
# 362406           NaN           NaN    299
# 362424  1.000000e+12  1.000000e+12    299
# 362426  1.920000e+02  1.920000e+02    299
# 362427  1.920000e+02  1.920000e+02    300
# 362440  7.500000e+02  7.500000e+02    299
# 362441  7.500000e+02  7.500000e+02    300
# 362468  8.000000e+02  8.000000e+02    299
# 362470  3.660000e+02  3.660000e+02    299
# 362474  1.000000e+12  1.000000e+12    300
# 362480  6.400000e+03  6.400000e+03    299
# 362515  5.380000e+02  5.380000e+02    299
# 362518  1.500000e+02  1.500000e+02    299
# 362524  6.000000e+02  6.000000e+02    300
# 362534  9.740000e+02  9.740000e+02    299
# 362537  7.500000e+02  4.000000e+02    299
# 362541  7.500000e+02  8.000000e+02    299
# 362542  7.500000e+02  8.000000e+02    299
# 362549  1.000000e+02  1.000000e+02    299
#
# [43146 rows x 72 columns]

# %%
#Mudando os rótulos categóricos
dados.V0302 = dados.V0302.astype('category')
dados.V0302.cat.categories =('Masculino', 'Feminino')
dados.V0302
# Out:
# 5          Feminino
# 6          Feminino
# 20        Masculino
# 38        Masculino
# 54        Masculino
# 64        Masculino
# 82        Masculino
# 86        Masculino
# 97        Masculino
# 101       Masculino
# 104       Masculino
# 118        Feminino
# 130       Masculino
# 143        Feminino
# 144       Masculino
# 149        Feminino
# 168        Feminino
# 176       Masculino
# 179        Feminino
# 191        Feminino
# 192       Masculino
# 195        Feminino
# 204        Feminino
# 214       Masculino
# 216        Feminino
# 227        Feminino
# 235       Masculino
# 240       Masculino
# 241        Feminino
# 247       Masculino
#             ...
# 362325     Feminino
# 362337     Feminino
# 362344    Masculino
# 362350     Feminino
# 362354     Feminino
# 362360    Masculino
# 362372     Feminino
# 362375     Feminino
# 362383    Masculino
# 362389     Feminino
# 362391     Feminino
# 362402     Feminino
# 362406    Masculino
# 362424     Feminino
# 362426    Masculino
# 362427    Masculino
# 362440     Feminino
# 362441     Feminino
# 362468    Masculino
# 362470     Feminino
# 362474    Masculino
# 362480    Masculino
# 362515    Masculino
# 362518     Feminino
# 362524     Feminino
# 362534    Masculino
# 362537     Feminino
# 362541    Masculino
# 362542     Feminino
# 362549    Masculino
# Name: V0302, dtype: category
# Categories (2, object): [Masculino, Feminino]

# %%
#Mudando os rótulos categóricos

dados.V0404 = dados.V0404.astype('category')
dados.V0404.cat.categories =('Indígena', 'Branca', 'Preta', 'Amarela','Parda')
dados.V0404
# Out:
# 5          Parda
# 6          Parda
# 20        Branca
# 38        Branca
# 54        Branca
# 64        Branca
# 82        Branca
# 86         Parda
# 97         Parda
# 101        Parda
# 104        Parda
# 118       Branca
# 130        Parda
# 143       Branca
# 144        Parda
# 149        Parda
# 168        Parda
# 176       Branca
# 179       Branca
# 191        Parda
# 192        Parda
# 195        Parda
# 204        Parda
# 214        Parda
# 216       Branca
# 227        Parda
# 235       Branca
# 240       Branca
# 241       Branca
# 247        Parda
#            ...
# 362325    Branca
# 362337     Parda
# 362344     Parda
# 362350    Branca
# 362354     Parda
# 362360     Parda
# 362372    Branca
# 362375     Parda
# 362383    Branca
# 362389     Parda
# 362391    Branca
# 362402     Parda
# 362406     Parda
# 362424    Branca
# 362426     Parda
# 362427     Parda
# 362440     Parda
# 362441     Preta
# 362468     Parda
# 362470    Branca
# 362474     Parda
# 362480    Branca
# 362515     Parda
# 362518     Parda
# 362524     Preta
# 362534     Parda
# 362537     Parda
# 362541    Branca
# 362542     Parda
# 362549     Preta
# Name: V0404, dtype: category
# Categories (5, object): [Indígena, Branca, Preta, Amarela, Parda]

# %%
#rotulos V6002
dados.V6002=dados.V6002.astype('category')
dados.V6002.cat.categories = ('Pública', 'Privada')

# %%
#rótulos V061111
dados.V061111=dados.V061111.astype('category')
dados.V061111.cat.categories = ('Acessam', 'Não Acessam')
dados.V061111
# Out:
# 5                 NaN
# 6                 NaN
# 20                NaN
# 38                NaN
# 54        Não Acessam
# 64        Não Acessam
# 82                NaN
# 86                NaN
# 97        Não Acessam
# 101       Não Acessam
# 104       Não Acessam
# 118       Não Acessam
# 130       Não Acessam
# 143               NaN
# 144               NaN
# 149               NaN
# 168       Não Acessam
# 176               NaN
# 179               NaN
# 191               NaN
# 192               NaN
# 195               NaN
# 204               NaN
# 214               NaN
# 216               NaN
# 227               NaN
# 235       Não Acessam
# 240               NaN
# 241           Acessam
# 247       Não Acessam
#              ...
# 362325            NaN
# 362337            NaN
# 362344            NaN
# 362350            NaN
# 362354            NaN
# 362360            NaN
# 362372            NaN
# 362375            NaN
# 362383            NaN
# 362389            NaN
# 362391            NaN
# 362402            NaN
# 362406            NaN
# 362424            NaN
# 362426            NaN
# 362427            NaN
# 362440            NaN
# 362441            NaN
# 362468            NaN
# 362470            NaN
# 362474            NaN
# 362480            NaN
# 362515    Não Acessam
# 362518            NaN
# 362524            NaN
# 362534            NaN
# 362537            NaN
# 362541            NaN
# 362542            NaN
# 362549            NaN
# Name: V061111, dtype: category
# Categories (2, object): [Acessam, Não Acessam]

# %%
#rótulos V4802
dados.V4802=dados.V4802.astype('category')

dados.V4802.cat.categories = (
'Alfabetização de adultos',
'1ª a 4ª séries do ensino fundamental regular em 8 anos ou de educação de jovens e adultos',
'5ª a 8ª séries do ensino fundamental regular em 8 anos ou de educação de jovens e adultos',
'1ª série do ensino fundamental regular em 9 anos',
'2ª a 5ª séries do ensino fundamental regular em 9 anos', 
'6ª a 9ª séries do ensino fundamental regular em 9 anos ',
'Educação de jovens e adultos não seriado do ensino fundamental',
'Ensino médio, inclusive pré-vestibular',
'Superior, inclusive mestrado ou doutorado')
dados.V4802
# Out:
# 5                 Superior, inclusive mestrado ou doutorado
# 6                    Ensino médio, inclusive pré-vestibular
# 20                   Ensino médio, inclusive pré-vestibular
# 38                   Ensino médio, inclusive pré-vestibular
# 54                                                      NaN
# 64                                                      NaN
# 82                                                      NaN
# 86                                                      NaN
# 97                                                      NaN
# 101                                                     NaN
# 104                                                     NaN
# 118                                                     NaN
# 130                                                     NaN
# 143               Superior, inclusive mestrado ou doutorado
# 144                  Ensino médio, inclusive pré-vestibular
# 149                  Ensino médio, inclusive pré-vestibular
# 168                                                     NaN
# 176       6ª a 9ª séries do ensino fundamental regular e...
# 179                  Ensino médio, inclusive pré-vestibular
# 191                                                     NaN
# 192                                                     NaN
# 195               Superior, inclusive mestrado ou doutorado
# 204                  Ensino médio, inclusive pré-vestibular
# 214                  Ensino médio, inclusive pré-vestibular
# 216                                                     NaN
# 227                                                     NaN
# 235                                                     NaN
# 240                                                     NaN
# 241                                                     NaN
# 247                                                     NaN
#                                 ...
# 362325                                                  NaN
# 362337                                                  NaN
# 362344                                                  NaN
# 362350               Ensino médio, inclusive pré-vestibular
# 362354                                                  NaN
# 362360               Ensino médio, inclusive pré-vestibular
# 362372               Ensino médio, inclusive pré-vestibular
# 362375            Superior, inclusive mestrado ou doutorado
# 362383            Superior, inclusive mestrado ou doutorado
# 362389            Superior, inclusive mestrado ou doutorado
# 362391                                                  NaN
# 362402            Superior, inclusive mestrado ou doutorado
# 362406                                                  NaN
# 362424               Ensino médio, inclusive pré-vestibular
# 362426                                                  NaN
# 362427                                                  NaN
# 362440            Superior, inclusive mestrado ou doutorado
# 362441               Ensino médio, inclusive pré-vestibular
# 362468                                                  NaN
# 362470            Superior, inclusive mestrado ou doutorado
# 362474                                                  NaN
# 362480               Ensino médio, inclusive pré-vestibular
# 362515                                                  NaN
# 362518    6ª a 9ª séries do ensino fundamental regular e...
# 362524               Ensino médio, inclusive pré-vestibular
# 362534                                                  NaN
# 362537               Ensino médio, inclusive pré-vestibular
# 362541                                                  NaN
# 362542            Superior, inclusive mestrado ou doutorado
# 362549               Ensino médio, inclusive pré-vestibular
# Name: V4802, dtype: category
# Categories (9, object): [Alfabetização de adultos, 1ª a 4ª séries do ensino fundamental regular e..., 5ª a 8ª séries do ensino fundamental regular e..., 1ª série do ensino fundamental regular em 9 anos, ..., 6ª a 9ª séries do ensino fundamental regular e..., Educação de jovens e adultos não seriado do en..., Ensino médio, inclusive pré-vestibular, Superior, inclusive mestrado ou doutorado]

# %%
# rotulos V0601
dados.V0601=dados.V0601.astype('category')
dados.V0601.cat.categories = ("Sim", "Não")
dados.V0601
# Out:
# 5         Sim
# 6         Sim
# 20        Sim
# 38        Sim
# 54        Sim
# 64        Sim
# 82        Sim
# 86        Sim
# 97        Sim
# 101       Sim
# 104       Sim
# 118       Não
# 130       Sim
# 143       Sim
# 144       Sim
# 149       Sim
# 168       Sim
# 176       Sim
# 179       Sim
# 191       Sim
# 192       Sim
# 195       Sim
# 204       Sim
# 214       Sim
# 216       Sim
# 227       Sim
# 235       Sim
# 240       Sim
# 241       Sim
# 247       Sim
#          ...
# 362325    Sim
# 362337    Sim
# 362344    Sim
# 362350    Sim
# 362354    Sim
# 362360    Sim
# 362372    Sim
# 362375    Sim
# 362383    Sim
# 362389    Sim
# 362391    Sim
# 362402    Sim
# 362406    Sim
# 362424    Sim
# 362426    Sim
# 362427    Sim
# 362440    Sim
# 362441    Sim
# 362468    Sim
# 362470    Sim
# 362474    Sim
# 362480    Sim
# 362515    Sim
# 362518    Sim
# 362524    Sim
# 362534    Sim
# 362537    Sim
# 362541    Sim
# 362542    Sim
# 362549    Sim
# Name: V0601, dtype: category
# Categories (2, object): [Sim, Não]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
sexo = dados.V0302.value_counts()
sexo.plot(kind='bar', color=('blue', 'pink'), legend=False, title='Gênero')

# %%
sexo.plot(kind='pie',colors=('blue', 'pink'), autopct="%0.2f",legend=False, title='Gênero')

# %%
cor = dados.V0404.value_counts()
cor.plot(kind='bar', color=('white', 'brown', 'black', 'yellow', 'red'), legend=False,title='Cor')

# %%
cor.plot(kind='pie', autopct="%0.2f",legend=False, title= 'Cor')

# %%
rede_ensino=dados.V6002.value_counts()
rede_ensino.plot(kind='bar', color=('blue', 'brown'), legend=False, title='rede de ensino')

# %%
rede_ensino.plot(kind='pie', colors=('blue', 'brown'), autopct="%0.2f",legend=False,title='rede de ensino')

# %%
nivel_ensino=dados.V4802.value_counts()
nivel_ensino.plot(kind='bar', color=('white', 'brown', 'black', 'yellow', 'red'), legend=False,title='nivel de ensino') # 2 é publica e 4 é privada; depois arrumamos

# %%
nivel_ensino.plot(kind='pie', colors=('blue', 'brown', 'pink', 'yellow', 'red'), autopct="%0.2f",legend=False,title='nivel de ensino')

# %%
ler=dados.V0601.value_counts()
ler.plot(kind='pie', autopct="%0.2f",legend=False,title='alfabetizados')

# %%
#V061111


internet=dados.V061111.value_counts()
internet.plot(kind='pie', autopct="%0.2f",title='Acessam internet')

# %%
ct= pd.crosstab(dados.V0302, dados.V0601)
ct.plot(kind='bar', color = ('yellow', 'salmon'))

# %%
ct
# Out:
# V0601        Sim  Não
# V0302
# Masculino  21550  354
# Feminino   21075  167

# %%
regiao = dados.UF
norte= dados[dados.UF <= 16] # 'Norte'
nordeste = dados[(dados.UF >= 17) & (dados.UF <= 29)] # 'Nordeste'
sudeste = dados[(dados.UF >= 31) & (dados.UF <= 35)] # 'Sudeste'
sul =dados[(dados.UF >= 41) & (dados.UF <= 43)] # 'Sul'
centro =dados[(dados.UF >=50 ) & (dados.UF <= 53)] # 'Centro'
#dados['Regiao']=pd.crosstab(dados)

renda = pd.cut(dados.V4742[dados.V4742 <1000000] ,bins= 10).value_counts()
renda.value_counts().plot.bar()

# %% [markdown]
# # Para o checkpoint:
# Reforçar a análise do Sr. Gold utilizando pelo menos duas variáveis quantitativas e explorando bem os recursos (histogramas, boxplots comparativos, comando .describe()).
# A idéia que motiva as análises precisa estar clara no texto, e as conclusões tiradas dos dados também.

# %%
dados.V8005
# Out:
# 5         19
# 6         17
# 20        17
# 38        17
# 54        20
# 64        21
# 82        22
# 86        19
# 97        22
# 101       19
# 104       21
# 118       18
# 130       18
# 143       19
# 144       17
# 149       17
# 168       17
# 176       16
# 179       19
# 191       22
# 192       20
# 195       18
# 204       16
# 214       16
# 216       18
# 227       18
# 235       19
# 240       22
# 241       22
# 247       19
#           ..
# 362325    19
# 362337    19
# 362344    20
# 362350    17
# 362354    19
# 362360    17
# 362372    18
# 362375    21
# 362383    20
# 362389    22
# 362391    21
# 362402    18
# 362406    20
# 362424    18
# 362426    19
# 362427    16
# 362440    18
# 362441    16
# 362468    22
# 362470    20
# 362474    19
# 362480    17
# 362515    17
# 362518    17
# 362524    16
# 362534    18
# 362537    18
# 362541    21
# 362542    22
# 362549    17
# Name: V8005, dtype: int64

# %%
idade = (dados.V8005.value_counts())/100
idade.plot(kind='box', legend=False,title='Idade')

# %%
renda=(dados.V4750.value_counts())
renda.plot(kind='box', legend=False,title='Renda')

#V4750
