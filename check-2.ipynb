# %% [markdown]
# ___
# # Atividade: Variáveis qualitativas com a PNAD (ALUNOS)
# ___
#
# ## Aula 02
#
#
# **Link úteis:**
# 1.	Leitura prévia necessária: Magalhães e Lima (7ª. Edição): pág. 9 a 16 – destacando para variáveis qualitativas.
# 2.	10 Minutes to Pandas: http://pandas.pydata.org/pandas-docs/stable/10min.html
# 3.	Essential Basic Functionality: http://pandas.pydata.org/pandas-docs/stable/basics.html
# 4.  Estude a aula `Aula02 Análise Exploratoria Variáveis Qualitativas-ALUNOS.ipynb`, o qual contém uma introdução ao Jupyter Notebook. A publicação dessa aula tem como objetivo auxiliá-lo, caso queira, no desenvolvimento dos seus próximos programas, como esta atividade.
#
# **Hoje:**
# 1.	Analisar variáveis qualitativas de forma uni e bivariadas utilizando tabelas de frequências e gráficos de barras e de pizza (ou setor).
# 2.  Trabalhar com a base de dados da PNAD 2013 - Pesquisa Nacional por Amostra de Domicílios
#
# **Próxima aula:**
# 1.	Leitura prévia necessária: Magalhães e Lima (7ª. Edição): pág. 9 a 17 – destacando para variáveis quantitativas; pág. 106 e 107 (Definição 4.1 e Exemplo 4.1).
#
# ___

# %% [markdown]
# ___
# ## <font color='blue'>PNAD 2013 – PESQUISA NACIONAL POR AMOSTRA DE DOMICÍLIOS</font>
#
# **Base de dados reduzida: ** `pes2013A.txt` (75 MB)
# [Acesse a base de dados aqui: https://dl.dropboxusercontent.com/u/65763596/Aula02/pes2013A.txt]
#
# **Dicionário das variáveis: ** `Dicionário de variáveis de pessoas - PNAD 2013.xlsx`
# [Acesse dicionário aqui: https://dl.dropboxusercontent.com/u/65763596/Aula02/Dicion%C3%A1rio%20de%20vari%C3%A1veis%20de%20pessoas%20-%20PNAD%202013.xls]
#
#
# Muitos especialistas na área de negócios dizem que empresários mais bem sucedidos são aqueles que fazem um planejamento antes de começar seu próprio negócio. Nessa visão, imagine que o Sr. Gold tenha como grande objetivo abrir uma nova faculdade e para isso deseja estudar o perfil do estudante que cursa ensino médio ou pré-vestibular e do que cursa ensino superior.
#
# Assuma que as variáveis de interesse a respeito dos estudantes sejam relativamente as mesmas de 2013 até o momento atual. Nesse caso, seja criativo para ajudar o Sr. Gold que deseja abrir seu negócio, mas não tem certeza sobre quais variáveis o interessam.
#
# Vocês podem ajudá-lo?!
#
# As variáveis a seguir devem fazer parte da sua análise:
#
# * V0302: sexo
# * V0404: cor ou raça
# * V6002: rede de ensino
# * V4802: nível de ensino e grupos de séries do ensino fundamental que frequentavam (todos os estudantes)
#
# ** Crie uma variável com região do indivíduo amostrado considerando a variável `UF` que define o estado e também trabalhe com essa nova variável em suas análises. **
#
# ** Escolha mais pelo menos DUAS variáveis qualitativas para completar sua análise!! **
#
# Faça uma análise exploratória apenas com as variáveis qualitativas com foco no objetivo do Sr. Gold.
#
# Sua análise deve conter pelo menos uma das seguintes visualizações:
#
# 1. Gráfico de colunas (bar) e setor (pie) com as frequências relativas cadas categorias das variáveis qualitativas.
# 2. Tabela cruzada entre pares de variaveis qualitativas. Montar o gráfico de colunas. Repetir o processo habilitando a opção "stacked=True".
#
#
# ___
#
#
#
# <font color='red'>
# Crie um repositório chamado CD em seu Github
# </font>
#
#
# Neste repositório, salve seu trabalho numa pasta chamada aula2
#
# Por exemplo, se seu login for *pikachu* o projeto vai estar na pasta:
#
# https://github.com/<font color=red>pikachu/CD/aula2</font>
#
#
#
# ## <font color='red'>Terça-feira (dia 16/08), no horário de atendimento da sua turma, deverá apresentar aos NINJAS!!</font>
# ___

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# /Users/WESLEY/Downloads

# %%
dados = pd.read_csv('pes2013A.txt', sep=" ")

# %% [markdown]
# ##  O senhor Gold é gaúcho, portando quer fazer uma faculdade no seu estado. Além disso, filtrou como interesse as idades de 16 anos (pré vestibular), até 23 anos, pois esta é a idade limite que ele quer para que entrem na sua faculdade.
# Variáveis que usamos foram se sabe ler e escrever (V0601) e se usou internet no último ano (V061111)
# ___

# %%
dados =dados[(dados.V8005 >= 16) & (dados.V8005 <23)] # V8005 é idade; filtrei para 16 anos (pré vestibular) até 23 (uma idade limite )
dados
# Out:
#         V0101  UF  V0102  V0103  V0301  V0302  V8005  V0404  V4011  V0412  \
# 5        2013  11     15      5      2      4     19      8      0      2
# 6        2013  11     15      5      3      4     17      8      0      2
# 20       2013  11     15     11      3      2     17      2      0      4
# 38       2013  11     23      5      2      2     17      2      0      6
# 54       2013  11     23     11      4      2     20      2      0      4
# 64       2013  11     23     14      4      2     21      2      0      4
# 82       2013  11     31      2      3      2     22      2      0      2
# 86       2013  11     31      4      3      2     19      8      0      4
# 97       2013  11     31      9      2      2     22      8      0      4
# 101      2013  11     31     10      3      2     19      8      0      2
# 104      2013  11     31     10      6      2     21      8      0      4
# 118      2013  11     31     13      2      4     18      2      0      4
# 130      2013  11     31     16      4      2     18      8      0      4
# 143      2013  11     40      3      2      4     19      2      0      2
# 144      2013  11     40      3      3      2     17      8      0      2
# 149      2013  11     40      4      3      4     17      8      0      2
# 168      2013  11     40     11      2      4     17      8      0      2
# 176      2013  11     40     16      3      2     16      2      0      2
# 179      2013  11     58      1      1      4     19      2      0      2
# 191      2013  11     58      5      3      4     22      8      5      4
# 192      2013  11     58      5      4      2     20      8      0      2
# 195      2013  11     58      6      3      4     18      8      0      4
# 204      2013  11     58     11      4      4     16      8      0      2
# 214      2013  11     58     13      6      2     16      8      0      4
# 216      2013  11     58     14      1      4     18      2      0      2
# 227      2013  11     58     17      3      4     18      8      0      4
# 235      2013  11     66      2      2      2     19      2      0      4
# 240      2013  11     66      4      1      2     22      2    NaN      4
# 241      2013  11     66      4      2      4     22      2    NaN      2
# 247      2013  11     66      6      3      2     19      8      0      4
# ...       ...  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 362325   2013  53   2091      8      4      4     19      2      0      4
# 362337   2013  53   2091     12      2      4     19      8      0      4
# 362344   2013  53   2091     14      3      2     20      8      0      4
# 362350   2013  53   2091     16      3      4     17      2      0      4
# 362354   2013  53   2091     16      7      4     19      8      0      2
# 362360   2013  53   2091     17      3      2     17      8      0      4
# 362372   2013  53   2105      1      3      4     18      2      0      6
# 362375   2013  53   2105      2      3      4     21      8      0      4
# 362383   2013  53   2105      5      4      2     20      2      0      4
# 362389   2013  53   2105      9      3      4     22      8      0      4
# 362391   2013  53   2105     11      1      4     21      2      0      2
# 362402   2013  53   2113      4      3      4     18      8      0      4
# 362406   2013  53   2113      6      2      2     20      8      0      4
# 362424   2013  53   2113     12      5      4     18      2      0      4
# 362426   2013  53   2113     13      2      2     19      8      0      4
# 362427   2013  53   2113     13      3      2     16      8      0      4
# 362440   2013  53   2121      2      3      4     18      8      0      2
# 362441   2013  53   2121      2      4      4     16      4      0      4
# 362468   2013  53   2121     14      1      2     22      8      0      2
# 362470   2013  53   2121     16      2      4     20      2      0      2
# 362474   2013  53   2121     17      3      2     19      8      0      4
# 362480   2013  53   2130      1      4      2     17      2      0      4
# 362515   2013  53   2148      1      3      2     17      8      0      4
# 362518   2013  53   2148      2      3      4     17      8      0      4
# 362524   2013  53   2148      5      3      4     16      4      0      4
# 362534   2013  53   2148      9      3      2     18      8      0      4
# 362537   2013  53   2148     10      1      4     18      8    NaN      2
# 362541   2013  53   2148     10      5      2     21      2      0      4
# 362542   2013  53   2148     10      6      4     22      8      0      2
# 362549   2013  53   2148     14      1      2     17      4      0      2
#
#         ...    V4706  V4707  V4809  V4810  V4711         V4718         V4720  \
# 5       ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 6       ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 20      ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 38      ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 54      ...        1      3     12      4      1  6.780000e+02  6.780000e+02
# 64      ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 82      ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 86      ...        1      4      5      6      1  6.000000e+02  6.000000e+02
# 97      ...        4      4      5      8      2  6.780000e+02  6.780000e+02
# 101     ...        9      3      4      8      2  6.000000e+02  6.000000e+02
# 104     ...        1      4      5      5      1  6.780000e+02  6.780000e+02
# 118     ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 130     ...        4      3      4      8      2  6.000000e+02  6.000000e+02
# 143     ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 144     ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 149     ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 168     ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 176     ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 179     ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 191     ...        1      3      9      4      1  8.000000e+02  8.000000e+02
# 192     ...       10      1      3      1      2  2.500000e+03  2.500000e+03
# 195     ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 204     ...        7      3     10      5      2  1.000000e+02  1.000000e+02
# 214     ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 216     ...        1      4      6      5      1  7.500000e+02  9.000000e+02
# 227     ...        1      2      6      5      1  8.000000e+02  8.000000e+02
# 235     ...        1      3      4      8      1  1.200000e+03  1.200000e+03
# 240     ...        3      3      8      2      1  1.400000e+03  1.400000e+03
# 241     ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 247     ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# ...     ...      ...    ...    ...    ...    ...           ...           ...
# 362325  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362337  ...        1      2      9      3      1  6.500000e+02  6.500000e+02
# 362344  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362350  ...        4      2     12      4      2  3.400000e+02  3.400000e+02
# 362354  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362360  ...        1      2     12      4      1  5.000000e+02  5.000000e+02
# 362372  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362375  ...        4      2      9      3      2  6.780000e+02  6.780000e+02
# 362383  ...        4      2     12      4      2  5.000000e+02  5.000000e+02
# 362389  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362391  ...        6      2     10      5      1  6.780000e+02  6.780000e+02
# 362402  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362406  ...        1      5      5      6      1  7.800000e+02  7.800000e+02
# 362424  ...      NaN    NaN    NaN    NaN    NaN           NaN  1.000000e+12
# 362426  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362427  ...        9      2      4      8      2  3.500000e+02  3.500000e+02
# 362440  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362441  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362468  ...        1      3      5      6      1  8.000000e+02  8.000000e+02
# 362470  ...        4      2     12      4      2  5.000000e+02  5.000000e+02
# 362474  ...        4      5      6      8      2  1.000000e+12  1.000000e+12
# 362480  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362515  ...      NaN    NaN    NaN    NaN    NaN           NaN  1.150000e+02
# 362518  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362524  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362534  ...        1      3     11      3      1  8.000000e+02  8.000000e+02
# 362537  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362541  ...        1      5     12      8      1  1.600000e+03  1.600000e+03
# 362542  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 362549  ...        7      2     10      5      2  1.000000e+02  1.000000e+02
#
#                V4742         V4750  V4729
# 5       2.660000e+02  2.660000e+02    243
# 6       2.660000e+02  2.660000e+02    243
# 20      2.800000e+02  2.800000e+02    243
# 38      6.660000e+02  6.660000e+02    243
# 54      2.710000e+02  2.710000e+02    243
# 64      8.000000e+02  8.000000e+02    243
# 82      2.000000e+03  2.000000e+03    244
# 86      8.620000e+02  8.620000e+02    243
# 97      3.390000e+02  3.390000e+02    244
# 101     2.120000e+02  2.120000e+02    243
# 104     2.120000e+02  2.120000e+02    243
# 118     0.000000e+00  0.000000e+00    244
# 130     1.090000e+02  1.090000e+02    244
# 143     0.000000e+00  0.000000e+00    243
# 144     0.000000e+00  0.000000e+00    243
# 149     4.560000e+02  4.560000e+02    244
# 168     1.660000e+02  1.660000e+02    243
# 176     5.800000e+02  5.800000e+02    244
# 179     6.280000e+02  6.280000e+02    243
# 191     1.800000e+03  1.800000e+03    244
# 192     1.800000e+03  1.800000e+03    244
# 195     6.660000e+02  6.660000e+02    243
# 204     3.550000e+02  3.550000e+02    243
# 214     1.000000e+12  4.000000e+02    243
# 216     4.500000e+02  4.500000e+02    243
# 227     6.400000e+02  6.400000e+02    243
# 235     1.200000e+03  1.200000e+03    243
# 240     7.000000e+02  7.000000e+02    243
# 241     7.000000e+02  7.000000e+02    244
# 247     2.460000e+02  2.460000e+02    243
# ...              ...           ...    ...
# 362325  7.500000e+02  7.500000e+02    299
# 362337  5.150000e+02  5.150000e+02    299
# 362344  5.250000e+02  5.250000e+02    299
# 362350  2.900000e+02  3.760000e+02    299
# 362354  2.900000e+02  1.600000e+02    300
# 362360  1.710000e+02  1.710000e+02    299
# 362372  4.520000e+02  4.520000e+02    300
# 362375  5.590000e+02  5.590000e+02    299
# 362383  1.000000e+12  1.000000e+12    299
# 362389  6.180000e+02  6.180000e+02    299
# 362391  3.390000e+02  3.390000e+02    299
# 362402  1.266000e+03  1.266000e+03    299
# 362406           NaN           NaN    299
# 362424  1.000000e+12  1.000000e+12    299
# 362426  1.920000e+02  1.920000e+02    299
# 362427  1.920000e+02  1.920000e+02    300
# 362440  7.500000e+02  7.500000e+02    299
# 362441  7.500000e+02  7.500000e+02    300
# 362468  8.000000e+02  8.000000e+02    299
# 362470  3.660000e+02  3.660000e+02    299
# 362474  1.000000e+12  1.000000e+12    300
# 362480  6.400000e+03  6.400000e+03    299
# 362515  5.380000e+02  5.380000e+02    299
# 362518  1.500000e+02  1.500000e+02    299
# 362524  6.000000e+02  6.000000e+02    300
# 362534  9.740000e+02  9.740000e+02    299
# 362537  7.500000e+02  4.000000e+02    299
# 362541  7.500000e+02  8.000000e+02    299
# 362542  7.500000e+02  8.000000e+02    299
# 362549  1.000000e+02  1.000000e+02    299
#
# [43146 rows x 72 columns]

# %%
dados =dados[(dados.UF == 43)] # 43 é o número do Rio Grande do Sul
dados
# Out:
#         V0101  UF  V0102  V0103  V0301  V0302  V8005  V0404  V4011  V0412  \
# 297842   2013  43     10      1      3      2     17      2      0      4
# 297846   2013  43     10      2      3      2     22      2      0      4
# 297853   2013  43     10      5      2      2     22      2      0      4
# 297854   2013  43     10      5      3      4     16      2      0      2
# 297857   2013  43     10      6      3      4     18      8      0      4
# 297869   2013  43     10     10      4      2     21      2      0      4
# 297873   2013  43     10     11      4      4     22      2      0      4
# 297889   2013  43     29      3      2      4     19      2      1      4
# 297897   2013  43     29      6      3      4     22      2      0      4
# 297901   2013  43     29      8      2      2     17      2      0      4
# 297905   2013  43     29     12      3      4     16      8      0      2
# 297914   2013  43     37      1      3      4     19      2      0      4
# 297915   2013  43     37      1      4      2     16      4      0      4
# 297930   2013  43     37      8      2      2     20      2      0      4
# 297931   2013  43     37      8      3      4     17      2      0      2
# 297937   2013  43     37     10      3      4     21      2      0      4
# 297941   2013  43     37     11      2      2     20      2      0      4
# 297945   2013  43     37     12      3      2     16      2      0      4
# 297956   2013  43     45      2      3      2     22      2      0      4
# 297965   2013  43     45      5      4      4     17      2      0      4
# 297966   2013  43     45      5      5      4     16      2      0      4
# 297971   2013  43     45      8      3      4     21      2      0      4
# 297977   2013  43     45     10      2      4     21      2      0      6
# 297978   2013  43     45     10      3      4     18      2      0      6
# 297987   2013  43     45     13      3      2     18      2      0      4
# 297991   2013  43     45     14      4      2     17      2      0      4
# 297995   2013  43     53      1      2      2     20      2      0      4
# 297997   2013  43     53      1      4      4     20      2      0      4
# 297998   2013  43     53      1      5      4     20      2      0      4
# 298004   2013  43     53      3      2      2     22      2      0      4
# ...       ...  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 324855   2013  43   7546     15      2      2     22      2      0      2
# 324866   2013  43   7546     21      1      2     22      2      0      2
# 324867   2013  43   7546     21      2      4     19      8      0      2
# 324870   2013  43   7546     22      3      4     20      2      0      4
# 324873   2013  43   7546     23      2      4     17      8      0      2
# 324877   2013  43   7546     26      2      2     19      2      0      4
# 324883   2013  43   7546     28      3      2     17      2      0      4
# 324893   2013  43   7546     30      3      2     17      2      0      6
# 324898   2013  43   7546     31      2      4     18      8      0      2
# 324899   2013  43   7546     31      3      2     20      8      0      2
# 324900   2013  43   7546     31      4      4     20      8      0      2
# 324907   2013  43   7546     34      4      4     20      2      0      4
# 324909   2013  43   7546     34      6      2     18      2      0      4
# 324910   2013  43   7546     34      7      4     17      2      0      4
# 324912   2013  43   7546     35      2      2     18      2      0      4
# 324915   2013  43   7546     36      3      2     22      2      0      4
# 324916   2013  43   7546     36      4      2     19      2      0      4
# 324928   2013  43   7546     39      7      4     19      4      0      2
# 324954   2013  43   7546     52      1      2     21      2    NaN      4
# 324976   2013  43   7562      1      3      4     21      2      0      4
# 324977   2013  43   7562      1      4      2     19      2      0      4
# 324980   2013  43   7562      3      3      4     18      2      0      2
# 324985   2013  43   7562      6      3      4     16      2      0      4
# 324997   2013  43   7562     15      3      2     22      2      0      4
# 324998   2013  43   7562     15      4      2     17      8      0      4
# 324999   2013  43   7562     15      5      4     22      2      0      4
# 325004   2013  43   7562     25      3      2     22      2      0      4
# 325013   2013  43   7562     36      3      2     18      2      0      4
# 325027   2013  43   7562     49      4      2     17      2      0      4
# 325028   2013  43   7562     49      5      4     17      2      0      4
#
#         ...    V4706  V4707  V4809  V4810  V4711         V4718         V4720  \
# 297842  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 297846  ...        2      3      8      9      2  1.400000e+03  1.400000e+03
# 297853  ...        7      4     10      5      2  2.000000e+03  2.000000e+03
# 297854  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 297857  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 297869  ...        1      3      3      8      1  1.600000e+03  1.600000e+03
# 297873  ...        1      3      9      3      1  1.300000e+03  1.300000e+03
# 297889  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 297897  ...        1      3     12      4      1  8.000000e+02  8.000000e+02
# 297901  ...        4      3      5      6      2  6.790000e+02  9.290000e+02
# 297905  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 297914  ...        1      3      3      4      1  8.000000e+02  8.000000e+02
# 297915  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 297930  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 297931  ...        4      4      5      8      2  8.500000e+02  8.500000e+02
# 297937  ...        1      4      5      6      1  8.000000e+02  8.000000e+02
# 297941  ...        4      3      8      4      2  6.780000e+02  6.780000e+02
# 297945  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 297956  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 297965  ...        1      4      5      6      1  7.950000e+02  7.950000e+02
# 297966  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 297971  ...        1      3      5      6      1  9.050000e+02  9.050000e+02
# 297977  ...        4      4     11      6      2  6.780000e+02  6.780000e+02
# 297978  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 297987  ...        1      2      5      5      1  6.780000e+02  6.780000e+02
# 297991  ...        1      4     12      4      1  6.780000e+02  6.780000e+02
# 297995  ...        4      3      8      8      2  8.000000e+02  8.000000e+02
# 297997  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 297998  ...        1      3      9      4      1  9.000000e+02  9.000000e+02
# 298004  ...        4      3      3      2      2  1.000000e+03  1.000000e+03
# ...     ...      ...    ...    ...    ...    ...           ...           ...
# 324855  ...        4      3      4      8      2  1.200000e+03  1.200000e+03
# 324866  ...        4      5      4      8      2  1.400000e+03  1.400000e+03
# 324867  ...        1      3      5      6      1  7.500000e+02  7.500000e+02
# 324870  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 324873  ...        7      1     10      5      2  6.000000e+02  6.000000e+02
# 324877  ...        1      4      3      5      1  1.200000e+03  1.200000e+03
# 324883  ...        4      5      4      8      2  1.000000e+12  1.000000e+12
# 324893  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 324898  ...        4      2      5      6      2  7.000000e+02  7.000000e+02
# 324899  ...        9      3      4      8      2  7.000000e+02  7.000000e+02
# 324900  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 324907  ...      NaN    NaN    NaN    NaN    NaN           NaN  6.780000e+02
# 324909  ...        4      3      4      8      2  1.000000e+12  1.000000e+12
# 324910  ...        1      5      5      4      1  1.000000e+12  1.000000e+12
# 324912  ...        4      4      4      8      2  7.000000e+02  7.000000e+02
# 324915  ...        1      5      4      8      1  2.000000e+03  2.000000e+03
# 324916  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 324928  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 324954  ...        1      5     12      5      1  1.350000e+03  1.350000e+03
# 324976  ...        4      3      3      5      2  4.000000e+02  4.000000e+02
# 324977  ...        4      5      1      7      2  6.000000e+02  6.000000e+02
# 324980  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 324985  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 324997  ...        4      2     12      4      2  6.780000e+02  6.780000e+02
# 324998  ...        4      3      8      4      2  5.400000e+02  5.400000e+02
# 324999  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 325004  ...        1      4      5      6      1  9.000000e+02  2.300000e+03
# 325013  ...      NaN    NaN    NaN    NaN    NaN           NaN  0.000000e+00
# 325027  ...        1      5      6      5      1  8.000000e+02  8.000000e+02
# 325028  ...        1      5      6      5      1  8.000000e+02  8.000000e+02
#
#                V4742         V4750  V4729
# 297842  9.000000e+02  9.000000e+02    242
# 297846  9.660000e+02  9.660000e+02    243
# 297853  1.000000e+03  1.000000e+03    242
# 297854  1.000000e+03  1.000000e+03    242
# 297857  3.330000e+02  3.330000e+02    243
# 297869  1.094000e+03  1.094000e+03    242
# 297873  1.300000e+03  1.300000e+03    242
# 297889  2.330000e+02  2.330000e+02    243
# 297897  5.460000e+02  5.460000e+02    242
# 297901  8.030000e+02  8.030000e+02    242
# 297905  2.600000e+02  2.600000e+02    242
# 297914  6.250000e+02  6.250000e+02    243
# 297915  6.250000e+02  6.250000e+02    243
# 297930  9.620000e+02  1.500000e+03    242
# 297931  9.620000e+02  4.250000e+02    243
# 297937  9.600000e+02  9.600000e+02    242
# 297941  1.118000e+03  1.118000e+03    242
# 297945  8.750000e+02  8.750000e+02    242
# 297956  5.330000e+02  5.330000e+02    242
# 297965  3.070000e+02  1.590000e+02    243
# 297966  3.070000e+02  1.590000e+02    242
# 297971  8.630000e+02  8.630000e+02    242
# 297977  8.920000e+02  8.920000e+02    242
# 297978  8.920000e+02  8.920000e+02    243
# 297987  6.590000e+02  6.590000e+02    242
# 297991  8.110000e+02  8.110000e+02    242
# 297995  5.330000e+02  5.750000e+02    242
# 297997  5.330000e+02  5.750000e+02    242
# 297998  5.330000e+02  4.500000e+02    242
# 298004  8.800000e+02  8.800000e+02    242
# ...              ...           ...    ...
# 324855  1.000000e+03  1.000000e+03    702
# 324866  1.075000e+03  1.075000e+03    703
# 324867  1.075000e+03  1.075000e+03    703
# 324870  1.000000e+12  1.000000e+12    703
# 324873  4.000000e+02  4.000000e+02    703
# 324877  4.820000e+02  6.670000e+02    703
# 324883  1.000000e+12  1.000000e+12    703
# 324893  2.160000e+02  2.160000e+02    703
# 324898  6.100000e+02  1.175000e+03    702
# 324899  6.100000e+02  2.330000e+02    702
# 324900  6.100000e+02  2.330000e+02    703
# 324907  1.000000e+12  3.510000e+02    702
# 324909  1.000000e+12  1.000000e+12    702
# 324910  1.000000e+12  1.000000e+12    703
# 324912  3.500000e+02  3.500000e+02    702
# 324915  8.500000e+02  8.500000e+02    702
# 324916  8.500000e+02  8.500000e+02    702
# 324928  1.340000e+02  1.500000e+02    703
# 324954  6.750000e+02  6.750000e+02    703
# 324976  4.500000e+02  5.000000e+02    702
# 324977  4.500000e+02  5.000000e+02    703
# 324980  3.400000e+02  3.400000e+02    703
# 324985  2.940000e+02  2.940000e+02    703
# 324997  1.083000e+03  1.083000e+03    703
# 324998  1.083000e+03  1.083000e+03    703
# 324999  1.083000e+03  1.083000e+03    703
# 325004  1.371000e+03  1.371000e+03    703
# 325013  3.000000e+02  3.000000e+02    703
# 325027  8.600000e+02  8.000000e+02    703
# 325028  8.600000e+02  8.000000e+02    703
#
# [2862 rows x 72 columns]

# %%
#Mudando os rótulos categóricos
dados.V0302 = dados.V0302.astype('category')
dados.V0302.cat.categories =('Masculino', 'Feminino')
dados.V0302
# Out:
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py:2387: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# 297842    Masculino
# 297846    Masculino
# 297853    Masculino
# 297854     Feminino
# 297857     Feminino
# 297869    Masculino
# 297873     Feminino
# 297889     Feminino
# 297897     Feminino
# 297901    Masculino
# 297905     Feminino
# 297914     Feminino
# 297915    Masculino
# 297930    Masculino
# 297931     Feminino
# 297937     Feminino
# 297941    Masculino
# 297945    Masculino
# 297956    Masculino
# 297965     Feminino
# 297966     Feminino
# 297971     Feminino
# 297977     Feminino
# 297978     Feminino
# 297987    Masculino
# 297991    Masculino
# 297995    Masculino
# 297997     Feminino
# 297998     Feminino
# 298004    Masculino
#             ...
# 324855    Masculino
# 324866    Masculino
# 324867     Feminino
# 324870     Feminino
# 324873     Feminino
# 324877    Masculino
# 324883    Masculino
# 324893    Masculino
# 324898     Feminino
# 324899    Masculino
# 324900     Feminino
# 324907     Feminino
# 324909    Masculino
# 324910     Feminino
# 324912    Masculino
# 324915    Masculino
# 324916    Masculino
# 324928     Feminino
# 324954    Masculino
# 324976     Feminino
# 324977    Masculino
# 324980     Feminino
# 324985     Feminino
# 324997    Masculino
# 324998    Masculino
# 324999     Feminino
# 325004    Masculino
# 325013    Masculino
# 325027    Masculino
# 325028     Feminino
# Name: V0302, dtype: category
# Categories (2, object): [Masculino, Feminino]

# %%
#Mudando os rótulos categóricos

dados.V0404 = dados.V0404.astype('category')
dados.V0404.cat.categories =('Indígena', 'Branca', 'Preta', 'Amarela','Parda')
dados.V0404
# Out:
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py:2387: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# 297842    Branca
# 297846    Branca
# 297853    Branca
# 297854    Branca
# 297857     Parda
# 297869    Branca
# 297873    Branca
# 297889    Branca
# 297897    Branca
# 297901    Branca
# 297905     Parda
# 297914    Branca
# 297915     Preta
# 297930    Branca
# 297931    Branca
# 297937    Branca
# 297941    Branca
# 297945    Branca
# 297956    Branca
# 297965    Branca
# 297966    Branca
# 297971    Branca
# 297977    Branca
# 297978    Branca
# 297987    Branca
# 297991    Branca
# 297995    Branca
# 297997    Branca
# 297998    Branca
# 298004    Branca
#            ...
# 324855    Branca
# 324866    Branca
# 324867     Parda
# 324870    Branca
# 324873     Parda
# 324877    Branca
# 324883    Branca
# 324893    Branca
# 324898     Parda
# 324899     Parda
# 324900     Parda
# 324907    Branca
# 324909    Branca
# 324910    Branca
# 324912    Branca
# 324915    Branca
# 324916    Branca
# 324928     Preta
# 324954    Branca
# 324976    Branca
# 324977    Branca
# 324980    Branca
# 324985    Branca
# 324997    Branca
# 324998     Parda
# 324999    Branca
# 325004    Branca
# 325013    Branca
# 325027    Branca
# 325028    Branca
# Name: V0404, dtype: category
# Categories (5, object): [Indígena, Branca, Preta, Amarela, Parda]

# %%
#rotulos V6002
dados.V6002=dados.V6002.astype('category')
dados.V6002.cat.categories = ('Pública', 'Privada')
# Out:
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py:2387: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
#rótulos V061111
dados.V061111=dados.V061111.astype('category')
dados.V061111.cat.categories = ('Acessam', 'Não Acessam')
dados.V061111
# Out:
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py:2387: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# 297842            NaN
# 297846            NaN
# 297853            NaN
# 297854            NaN
# 297857            NaN
# 297869            NaN
# 297873            NaN
# 297889    Não Acessam
# 297897            NaN
# 297901    Não Acessam
# 297905            NaN
# 297914            NaN
# 297915            NaN
# 297930            NaN
# 297931            NaN
# 297937            NaN
# 297941            NaN
# 297945            NaN
# 297956    Não Acessam
# 297965            NaN
# 297966            NaN
# 297971            NaN
# 297977            NaN
# 297978    Não Acessam
# 297987            NaN
# 297991            NaN
# 297995            NaN
# 297997            NaN
# 297998            NaN
# 298004    Não Acessam
#              ...
# 324855            NaN
# 324866            NaN
# 324867            NaN
# 324870            NaN
# 324873    Não Acessam
# 324877            NaN
# 324883            NaN
# 324893    Não Acessam
# 324898            NaN
# 324899            NaN
# 324900            NaN
# 324907    Não Acessam
# 324909    Não Acessam
# 324910    Não Acessam
# 324912            NaN
# 324915    Não Acessam
# 324916    Não Acessam
# 324928            NaN
# 324954            NaN
# 324976            NaN
# 324977            NaN
# 324980            NaN
# 324985            NaN
# 324997            NaN
# 324998            NaN
# 324999            NaN
# 325004            NaN
# 325013        Acessam
# 325027            NaN
# 325028            NaN
# Name: V061111, dtype: category
# Categories (2, object): [Acessam, Não Acessam]

# %%
#rótulos V4802
dados.V4802=dados.V4802.astype('category')

dados.V4802.cat.categories = (
'Alfabetização de adultos',
'1ª a 4ª séries do ensino fundamental regular em 8 anos ou de educação de jovens e adultos',
'5ª a 8ª séries do ensino fundamental regular em 8 anos ou de educação de jovens e adultos',
'1ª série do ensino fundamental regular em 9 anos',
'2ª a 5ª séries do ensino fundamental regular em 9 anos', 
'6ª a 9ª séries do ensino fundamental regular em 9 anos ',
'Educação de jovens e adultos não seriado do ensino fundamental',
'Ensino médio, inclusive pré-vestibular',
'Superior, inclusive mestrado ou doutorado')
dados.V4802
# Out:
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py:2387: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# 297842               Ensino médio, inclusive pré-vestibular
# 297846                                                  NaN
# 297853                                                  NaN
# 297854               Ensino médio, inclusive pré-vestibular
# 297857                                                  NaN
# 297869                                                  NaN
# 297873                                                  NaN
# 297889                                                  NaN
# 297897            Superior, inclusive mestrado ou doutorado
# 297901                                                  NaN
# 297905    6ª a 9ª séries do ensino fundamental regular e...
# 297914                                                  NaN
# 297915               Ensino médio, inclusive pré-vestibular
# 297930                                                  NaN
# 297931                                                  NaN
# 297937                                                  NaN
# 297941                                                  NaN
# 297945               Ensino médio, inclusive pré-vestibular
# 297956                                                  NaN
# 297965               Ensino médio, inclusive pré-vestibular
# 297966               Ensino médio, inclusive pré-vestibular
# 297971                                                  NaN
# 297977                                                  NaN
# 297978                                                  NaN
# 297987                                                  NaN
# 297991               Ensino médio, inclusive pré-vestibular
# 297995                                                  NaN
# 297997                                                  NaN
# 297998                                                  NaN
# 298004                                                  NaN
#                                 ...
# 324855                                                  NaN
# 324866                                                  NaN
# 324867                                                  NaN
# 324870            Superior, inclusive mestrado ou doutorado
# 324873                                                  NaN
# 324877                                                  NaN
# 324883                                                  NaN
# 324893                                                  NaN
# 324898               Ensino médio, inclusive pré-vestibular
# 324899                                                  NaN
# 324900                                                  NaN
# 324907                                                  NaN
# 324909                                                  NaN
# 324910                                                  NaN
# 324912                                                  NaN
# 324915                                                  NaN
# 324916                                                  NaN
# 324928                                                  NaN
# 324954                                                  NaN
# 324976                                                  NaN
# 324977                                                  NaN
# 324980                                                  NaN
# 324985               Ensino médio, inclusive pré-vestibular
# 324997                                                  NaN
# 324998            Superior, inclusive mestrado ou doutorado
# 324999               Ensino médio, inclusive pré-vestibular
# 325004            Superior, inclusive mestrado ou doutorado
# 325013    2ª a 5ª séries do ensino fundamental regular e...
# 325027               Ensino médio, inclusive pré-vestibular
# 325028               Ensino médio, inclusive pré-vestibular
# Name: V4802, dtype: category
# Categories (9, object): [Alfabetização de adultos, 1ª a 4ª séries do ensino fundamental regular e..., 5ª a 8ª séries do ensino fundamental regular e..., 1ª série do ensino fundamental regular em 9 anos, ..., 6ª a 9ª séries do ensino fundamental regular e..., Educação de jovens e adultos não seriado do en..., Ensino médio, inclusive pré-vestibular, Superior, inclusive mestrado ou doutorado]

# %%
# rotulos V0601
dados.V0601=dados.V0601.astype('category')
dados.V0601.cat.categories = ("Sim", "Não")
dados.V0601
# Out:
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py:2387: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# 297842    Sim
# 297846    Sim
# 297853    Sim
# 297854    Sim
# 297857    Sim
# 297869    Sim
# 297873    Sim
# 297889    Sim
# 297897    Sim
# 297901    Sim
# 297905    Sim
# 297914    Sim
# 297915    Sim
# 297930    Sim
# 297931    Sim
# 297937    Sim
# 297941    Sim
# 297945    Sim
# 297956    Sim
# 297965    Sim
# 297966    Sim
# 297971    Sim
# 297977    Sim
# 297978    Não
# 297987    Sim
# 297991    Sim
# 297995    Sim
# 297997    Sim
# 297998    Sim
# 298004    Sim
#          ...
# 324855    Sim
# 324866    Sim
# 324867    Sim
# 324870    Sim
# 324873    Sim
# 324877    Sim
# 324883    Sim
# 324893    Sim
# 324898    Sim
# 324899    Sim
# 324900    Sim
# 324907    Não
# 324909    Sim
# 324910    Sim
# 324912    Sim
# 324915    Sim
# 324916    Sim
# 324928    Sim
# 324954    Sim
# 324976    Sim
# 324977    Sim
# 324980    Sim
# 324985    Sim
# 324997    Sim
# 324998    Sim
# 324999    Sim
# 325004    Sim
# 325013    Sim
# 325027    Sim
# 325028    Sim
# Name: V0601, dtype: category
# Categories (2, object): [Sim, Não]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
sexo = dados.V0302.value_counts()
sexo.plot(kind='bar', color=('blue', 'pink'), legend=False, title='Gênero')

# %%
sexo.plot(kind='pie',colors=('blue', 'pink'), autopct="%0.2f",legend=False, title='Gênero')

# %%
cor = dados.V0404.value_counts()
cor.plot(kind='bar', color=('white', 'brown', 'black', 'yellow', 'red'), legend=False,title='Cor')

# %%
cor.plot(kind='pie', autopct="%0.2f",legend=False, title= 'Cor')

# %%
rede_ensino=dados.V6002.value_counts()
rede_ensino.plot(kind='bar', color=('blue', 'brown'), legend=False, title='rede de ensino')

# %%
rede_ensino.plot(kind='pie', colors=('blue', 'brown'), autopct="%0.2f",legend=False,title='rede de ensino')

# %%
nivel_ensino=dados.V4802.value_counts()
nivel_ensino.plot(kind='bar', color=('white', 'brown', 'black', 'yellow', 'red'), legend=False,title='nivel de ensino') # 2 é publica e 4 é privada; depois arrumamos

# %%
nivel_ensino.plot(kind='pie', colors=('blue', 'brown', 'pink', 'yellow', 'red'), autopct="%0.2f",legend=False,title='nivel de ensino')

# %%
ler = dados.V0601.value_counts()
ler.plot(kind='bar', color=('red', 'blue', 'black', 'yellow', 'red'), legend=False,title='alfabetizados') # 2 é publica e 4 é privada; depois arrumamos

# %%
ler=dados.V0601.value_counts()
ler.plot(kind='pie', autopct="%0.2f",legend=False,title='alfabetizados')

# %%
internet=dados.V061111.value_counts()
internet.plot(kind='bar', color=('red', 'blue', 'black', 'yellow', 'red'), legend=False,title='Acessam Internet') # 2 é publica e 4 é privada; depois arrumamos

# %%
#V061111
internet=dados.V061111.value_counts()
internet.plot(kind='pie', autopct="%0.2f",title='Acessam internet')

# %%
ct= pd.crosstab(dados.V0302, dados.V0601)
ct.plot(kind='bar', color = ('yellow', 'salmon'))

# %%
ct
# Out:
# V0601       Sim  Não
# V0302
# Masculino  1442   16
# Feminino   1396    8

# %%
regiao = dados.UF
regiao[dados.UF <= 16] = 'Norte'
regiao[(dados.UF >= 17) & (dados.UF <= 29)] = 'Nordeste'
regiao[(dados.UF >= 31) & (dados.UF <= 35)] = 'Sudeste'
regiao[(dados.UF >= 41) & (dados.UF <= 43)] = 'Sul'
regiao[(dados.UF >=50 ) & (dados.UF <= 53)] = 'Centro'
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py:4059: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# //anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2885: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-a39aa7b1f8ec> in <module>()
#       4 regiao[(dados.UF >= 31) & (dados.UF <= 35)] = 'Sudeste'
#       5 regiao[(dados.UF >= 41) & (dados.UF <= 43)] = 'Sul'
# ----> 6 regiao[(dados.UF >=50 ) & (dados.UF <= 53)] = 'Centro'
#
# //anaconda/lib/python3.5/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     724                 other = np.asarray(other)
#     725
# --> 726             res = na_op(values, other)
#     727             if isscalar(res):
#     728                 raise TypeError('Could not compare %s type with Series'
#
# //anaconda/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#     646                     result = lib.vec_compare(x, y, op)
#     647             else:
# --> 648                 result = lib.scalar_compare(x, y, op)
#     649         else:
#     650
#
# pandas/lib.pyx in pandas.lib.scalar_compare (pandas/lib.c:14186)()
#
# TypeError: unorderable types: str() >= int()

# %%
renda = pd.cut(dados.V4742, bins=10).value_counts()
renda.value_counts().plot.bar()

# %%
renda.value_counts()
# Out:
# 0       99998
# 2718        1
# 129         1
# dtype: int64
